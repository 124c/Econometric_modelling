# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.api import VAR
import os

# %% [markdown]
# https://rosstat.gov.ru/statistics/price
# - Структура потребительских расходов населения по товарам (услугам)-представителям для расчета ИПЦ по Российской Федерации в 2004-2026 гг.

# %%
df_pi2rs = pd.read_excel(os.path.join(fd_ru,'PriceConsumer.xlsx'), sheet_name = 'MAP_PI_RS') \
.query("TYPE == 'Goods'") \
.dropna(subset='Pi')

# %%
pi_mm_sa = pd.read_excel('data_Shapiro_inflation_decomposition/indicators_cpd.xlsx'
, sheet_name = "MM_SA_BR"
 , skiprows = range(1,11)
 , index_col='ds') \
 .resample('M').last() \
 [df_pi2rs.Pi.to_list()]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Projects/Econometric_modelling/.venv/lib/python3.12/site-packages/pandas/compat/_optional.py:158, in import_optional_dependency(name, extra, min_version, errors)
#     157 try:
# --> 158     module = importlib.import_module(name)
#     159 except ImportError as err:
#
# File /usr/local/Cellar/python@3.12/3.12.12_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
import os
os.getcwd()
# Out:
# '/Users/mikayilmajidov/Projects/Econometric_modelling/Macro'
